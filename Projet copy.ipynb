# %%
companies = [
    "Nvidia",
    "Apple",
    "Alphabet",
    "Microsoft",
    "Amazon",
    "Broadcom",
    "Meta",
    "Tesla",
    "Oracle",
    "Advanced Micro Devices",
    "JPMorgan Chase",
    "Bank of America",
    "Citigroup",
    "Wells Fargo",
    "Goldman Sachs",
    "Morgan Stanley",
    "BlackRock",
    "American Express",
    "Charles Schwab",
    "Mastercard"
]

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
# Out:
#      input_name wikidata_id wikidata_label ticker_wikidata  \
# 0        Amazon       Q3884         Amazon            None
# 1        Amazon       Q3884         Amazon            None
# 2        Amazon       Q3884         Amazon            None
# 3        Amazon       Q3884         Amazon            None
# 4        Amazon     Q456085         Amazon            None
# ..          ...         ...            ...             ...
# 66        Tesla    Q1548225          Tesla            None
# 67        Tesla   Q78157177          Tesla            None
# 68  Wells Fargo     Q744149    Wells Fargo            None
# 69  Wells Fargo     Q744149    Wells Fargo            None
# 70  Wells Fargo     Q744149    Wells Fargo            None
#
#                     industry         country                 exchange
# 0                     retail   United States                   Nasdaq
# 1                web service   United States                   Nasdaq
# 2                 e-commerce   United States                   Nasdaq
# 3        web hosting service   United States                   Nasdaq
# 4        automotive industry             NaN                      NaN
# ..                       ...             ...                      ...
# 66  industrial manufacturing  Czech Republic                      NaN
# 67                       NaN  Czechoslovakia                      NaN
# 68      economics of banking   United States  New York Stock Exchange
# 69        financial services   United States  New York Stock Exchange
# 70          financial sector   United States  New York Stock Exchange
#
# [71 rows x 7 columns]
